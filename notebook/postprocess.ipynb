# %%
# %load_ext autoreload
# %autoreload 2
    
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import seaborn as sns
import matplotlib.pyplot as plt
from glyphosate_resistant.preprocess import extract_species_abundance,expand_taxonomic_column
from glyphosate_resistant.postprocess import load_deepec_results,summarize_ec_completeness,summarize_taxa_completion,plot_taxa_completion_horizontal,stacked_bar_multiple_group
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
species_top_general =  pd.read_csv("../data/processed/top_species_all.tsv", sep = "\t")
species_top_asd =  pd.read_csv("../data/processed/top_species_ASD.tsv", sep = "\t")
species_top_ctrl =  pd.read_csv("../data/processed/top_species_Control.tsv", sep = "\t")

species_top_general['Status'] = 'general'
species_top_asd['Status'] = 'asd'
species_top_ctrl['Status'] = 'ctrl'

# %%
enzymes = {
    "aroF_G_H": "2.5.1.54",
    "aroB": "4.2.3.4",
    "aroD": "4.2.1.10",
    "aroE": "1.1.1.25",
    "aroK_L": "2.7.1.71",
    "aroA": "2.5.1.19",
    "aroC": "4.2.3.5"
}

# %%
combined_result_contorl = load_deepec_results("../data/result/Ctrl/*/DeepECv2_result.txt")
combined_result_asd= load_deepec_results("../data/result/ASD/*/DeepECv2_result.txt")
combined_result_general = load_deepec_results("../data/result/general/*/DeepECv2_result.txt")

# %%
combined_result_contorl
# Out:
#                 sequence_ID    prediction  EC number                 Species
# 0            WP_003808114.1          None        NaN  Bifidobacterium_longum
# 1            WP_003808136.1          None        NaN  Bifidobacterium_longum
# 2            WP_003812809.1          None        NaN  Bifidobacterium_longum
# 3            WP_003813881.1          None        NaN  Bifidobacterium_longum
# 4            WP_003814508.1          None        NaN  Bifidobacterium_longum
# ...                     ...           ...        ...                     ...
# 216086  DBGABJ010000503.1_7          None        NaN    Phocaeicola_plebeius
# 216087  DBGABJ010000503.1_8          None        NaN    Phocaeicola_plebeius
# 216088  DBGABJ010000504.1_1    EC:5.2.1.8    5.2.1.8    Phocaeicola_plebeius
# 216089  DBGABJ010000504.1_2    EC:5.2.1.8    5.2.1.8    Phocaeicola_plebeius
# 216090  DBGABJ010000504.1_3  EC:2.3.1.286  2.3.1.286    Phocaeicola_plebeius
#
# [216091 rows x 4 columns]

# %%
summary_df_ctrl = summarize_ec_completeness(combined_result_contorl, enzymes,'control')
summary_df_asd = summarize_ec_completeness(combined_result_asd, enzymes,'ASD')
summary_df_general = summarize_ec_completeness(combined_result_general, enzymes,'general')
#sum(summary_df_general['Completeness (%)']==100)/len(summary_df_general.index)

# %%
summary_df_general
# Out:
#                             Species  \
# 34                Coprococcus_comes
# 28                 Blautia_wexlerae
# 31  Clostridiales_bacterium_KLE1615
# 33                Coprococcus_catus
# 69              Ruminococcus_gnavus
# ..                              ...
# 20          Bifidobacterium_bifidum
# 19     Bifidobacterium_adolescentis
# 61            Romboutsia_timonensis
# 77             Vescimonas_coprocola
# 36                Dialister_invisus
#
#                                          Detected ECs  Completeness (%)  \
# 34  {4.2.1.10, 4.2.3.5, 4.2.3.4, 2.5.1.54, 2.5.1.1...        100.000000
# 28  {4.2.1.10, 1.1.1.25, 4.2.3.5, 2.5.1.19, 2.5.1....        100.000000
# 31  {4.2.1.10, 1.1.1.25, 4.2.3.5, 2.5.1.54, 2.5.1....        100.000000
# 33  {4.2.1.10, 1.1.1.25, 4.2.3.5, 2.5.1.54, 2.5.1....        100.000000
# 69  {4.2.1.10, 4.2.3.5, 4.2.3.4, 2.5.1.54, 2.5.1.1...        100.000000
# ..                                                ...               ...
# 20  {4.2.1.10, 4.2.3.5, 2.5.1.54, 2.5.1.19, 1.1.1.25}         71.428571
# 19  {4.2.1.10, 4.2.3.5, 2.5.1.54, 2.5.1.19, 1.1.1.25}         71.428571
# 61             {2.5.1.19, 2.5.1.54, 4.2.3.4, 4.2.3.5}         57.142857
# 77            {2.5.1.19, 4.2.1.10, 2.7.1.71, 4.2.3.4}         57.142857
# 36                                {2.7.1.71, 4.2.3.4}         28.571429
#
#      Status
# 34  general
# 28  general
# 31  general
# 33  general
# 69  general
# ..      ...
# 20  general
# 19  general
# 61  general
# 77  general
# 36  general
#
# [78 rows x 4 columns]

# %%
combined_df = pd.concat([summary_df_ctrl, summary_df_asd, summary_df_general], ignore_index=True)

# Violin plot
sns.violinplot(data=combined_df, x='Status', y='Completeness (%)', inner='box')
plt.title('EC Pathway Completeness Comparison')
plt.show()

# %%
sns.kdeplot(summary_df_ctrl['Completeness (%)'], label='Control', fill=True)
sns.kdeplot(summary_df_asd['Completeness (%)'], label='Disease', fill=True)
sns.kdeplot(summary_df_general['Completeness (%)'], label='general', fill=True)

plt.title('Density of EC Completeness')
plt.xlabel('Completeness (%)')
plt.ylabel('Density')
plt.legend(loc='upper left')
plt.show()

# %%
from scipy.stats import mannwhitneyu

stat, p = mannwhitneyu(summary_df_ctrl['Completeness (%)'], summary_df_asd['Completeness (%)'])
print(f"Mann-Whitney U p-value: {p:.4f}")
# Out:
# Mann-Whitney U p-value: 0.4931

# %%
abudance = pd.read_csv("../data/raw/Internal2_metaphlan_merged_abundance_table.txt",sep="\t", comment='#')

# %%
collapsed_abundance = expand_taxonomic_column(abudance)
#collapsed_abundance.to_csv("../data/processed/full_collapsed_abundance.csv")
# Out:
#        kingdom          phylum                class               order  \
# 0     Bacteria             NaN                  NaN                 NaN
# 1     Bacteria      Firmicutes                  NaN                 NaN
# 2     Bacteria   Bacteroidetes                  NaN                 NaN
# 3     Bacteria  Actinobacteria                  NaN                 NaN
# 4     Bacteria  Proteobacteria                  NaN                 NaN
# ...        ...             ...                  ...                 ...
# 2668  Bacteria      Firmicutes            CFGB76102           OFGB76102
# 2669  Bacteria      Firmicutes         Tissierellia      Tissierellales
# 2670  Bacteria  Proteobacteria  Deltaproteobacteria  Desulfovibrionales
# 2671  Bacteria  Proteobacteria  Deltaproteobacteria  Desulfovibrionales
# 2672  Bacteria  Proteobacteria  Deltaproteobacteria  Desulfovibrionales
#
#                    family         genus                species    strain
# 0                     NaN           NaN                    NaN       NaN
# 1                     NaN           NaN                    NaN       NaN
# 2                     NaN           NaN                    NaN       NaN
# 3                     NaN           NaN                    NaN       NaN
# 4                     NaN           NaN                    NaN       NaN
# ...                   ...           ...                    ...       ...
# 2668             FGB76102       GGB3523       GGB3523_SGB66046  SGB66046
# 2669     Peptoniphilaceae  Anaerococcus  Anaerococcus_SGB53821  SGB53821
# 2670  Desulfovibrionaceae      GGB79709                    NaN       NaN
# 2671  Desulfovibrionaceae      GGB79709      GGB79709_SGB27377       NaN
# 2672  Desulfovibrionaceae      GGB79709      GGB79709_SGB27377  SGB27377
#
# [2673 rows x 8 columns]

# %%
df_disease = summary_df_asd.merge(species_top_asd, on="Species")
df_ctrl = summary_df_ctrl.merge(species_top_ctrl, on="Species")
df_general = summary_df_general.merge(species_top_general, on="Species")

df_all = pd.concat([df_disease, df_ctrl, df_general])
df_all["Importance"] = df_all["Completeness (%)"] * df_all["Average_Abundance"]

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_all, x="Status", y="Importance", palette="Set1")
plt.title("Importance Score by Group (Abundance × Completeness)")
plt.ylabel("Importance")
plt.yscale("log")  # If skewed
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df_all, x="Importance", hue="Status", fill=True, common_norm=False)
plt.title("Density of Abundance-Weighted Completeness by Group")
plt.xlabel("Weighted Completeness")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
asd_taxa = collapsed_abundance.merge(species_top_asd, left_on="species", right_on = "Species",how="right")
ctrl_taxa = collapsed_abundance.merge(species_top_ctrl, left_on="species", right_on = "Species",how="right")
general_taxa = collapsed_abundance.merge(species_top_general, left_on="species", right_on = "Species",how="right")
combine_taxa = pd.concat([asd_taxa,ctrl_taxa,general_taxa])

# %%
general_taxa_completeness = general_taxa.merge(df_general)
ctrl_taxa_completeness = ctrl_taxa.merge(df_ctrl)
asd_taxa_completeness = asd_taxa.merge(df_disease)

# %%
combine_taxa
# Out:
#                                             clade_name  \
# 0    k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 1    k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 2    k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 3    k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 4    k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# ..                                                 ...
# 226  k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 227  k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 228  k__Bacteria|p__Firmicutes|c__Clostridia|o__Eub...
# 229  k__Bacteria|p__Firmicutes|c__Negativicutes|o__...
# 230  k__Bacteria|p__Firmicutes|c__Negativicutes|o__...
#
#      001-00-54-1A_CP05063_L001_taxonomic  001-00-54-2A_CP05063_L001_taxonomic  \
# 0                                2.21319                              1.89210
# 1                                2.21319                              1.89210
# 2                                0.00000                              0.00000
# 3                               17.19871                             20.72290
# 4                                7.81245                             10.86311
# ..                                   ...                                  ...
# 226                              0.16742                              0.08063
# 227                              0.00000                              0.00000
# 228                              0.00000                              0.00000
# 229                              0.00000                              0.00000
# 230                              0.00000                              0.00000
#
#      001-0001-1_CP05063_L001_taxonomic  001-0002-1_CP05063_L001_taxonomic  \
# 0                              2.44589                            6.46754
# 1                              2.44589                            6.46754
# 2                              0.00000                            0.00000
# 3                              0.00000                           10.28202
# 4                              0.00000                            6.73320
# ..                                 ...                                ...
# 226                            0.00000                            0.00000
# 227                            0.00000                            0.00000
# 228                            0.00000                            0.00000
# 229                            0.00000                            0.00000
# 230                            0.00000                            0.00000
#
#      001-0003-1_CP05063_L001_taxonomic  001-0006-1_CP05063_L001_taxonomic  \
# 0                             15.25314                            0.09066
# 1                             15.25314                            0.09066
# 2                              0.00000                            0.00000
# 3                              4.29856                            0.03187
# 4                              2.67784                            0.01383
# ..                                 ...                                ...
# 226                            0.00000                            0.57038
# 227                            0.00570                            0.00000
# 228                            0.00570                            0.00000
# 229                            0.47967                            0.00000
# 230                            0.47967                            0.00000
#
#      001-0007-1_CP05063_L001_taxonomic  001-0009-1_CP05063_L001_taxonomic  \
# 0                             20.26919                            6.44567
# 1                             20.26919                            6.04879
# 2                              0.00000                            0.39689
# 3                              8.52961                           13.05774
# 4                              2.90711                            4.10626
# ..                                 ...                                ...
# 226                            0.05779                            0.00000
# 227                            0.00000                            0.00000
# 228                            0.00000                            0.00000
# 229                            0.00000                            0.00000
# 230                            0.00000                            0.00000
#
#      001-0010-1_CP05063_L001_taxonomic  ...   kingdom      phylum  \
# 0                              4.60158  ...  Bacteria  Firmicutes
# 1                              3.41548  ...  Bacteria  Firmicutes
# 2                              1.18611  ...  Bacteria  Firmicutes
# 3                              4.07783  ...  Bacteria  Firmicutes
# 4                              2.42822  ...  Bacteria  Firmicutes
# ..                                 ...  ...       ...         ...
# 226                            0.00000  ...  Bacteria  Firmicutes
# 227                            0.01443  ...  Bacteria  Firmicutes
# 228                            0.01443  ...  Bacteria  Firmicutes
# 229                            0.00000  ...  Bacteria  Firmicutes
# 230                            0.00000  ...  Bacteria  Firmicutes
#
#              class              order              family             genus  \
# 0       Clostridia      Eubacteriales     Lachnospiraceae           Blautia
# 1       Clostridia      Eubacteriales     Lachnospiraceae           Blautia
# 2       Clostridia      Eubacteriales     Lachnospiraceae           Blautia
# 3       Clostridia      Eubacteriales    Oscillospiraceae  Faecalibacterium
# 4       Clostridia      Eubacteriales    Oscillospiraceae  Faecalibacterium
# ..             ...                ...                 ...               ...
# 226     Clostridia      Eubacteriales    Oscillospiraceae             Other
# 227     Clostridia      Eubacteriales    Oscillospiraceae  Faecalibacterium
# 228     Clostridia      Eubacteriales    Oscillospiraceae  Faecalibacterium
# 229  Negativicutes  Acidaminococcales  Acidaminococcaceae             Other
# 230  Negativicutes  Acidaminococcales  Acidaminococcaceae             Other
#
#                            species    strain                        Species  \
# 0                 Blautia_wexlerae       NaN               Blautia_wexlerae
# 1                 Blautia_wexlerae   SGB4837               Blautia_wexlerae
# 2                 Blautia_wexlerae   SGB4831               Blautia_wexlerae
# 3     Faecalibacterium_prausnitzii       NaN   Faecalibacterium_prausnitzii
# 4     Faecalibacterium_prausnitzii  SGB15318   Faecalibacterium_prausnitzii
# ..                             ...       ...                            ...
# 226           Vescimonas_coprocola  SGB15089           Vescimonas_coprocola
# 227      Faecalibacterium_SGB15315       NaN      Faecalibacterium_SGB15315
# 228      Faecalibacterium_SGB15315  SGB15315      Faecalibacterium_SGB15315
# 229  Phascolarctobacterium_faecium       NaN  Phascolarctobacterium_faecium
# 230  Phascolarctobacterium_faecium   SGB5792  Phascolarctobacterium_faecium
#
#      Average_Abundance
# 0             7.566266
# 1             7.566266
# 2             7.566266
# 3             6.537086
# 4             6.537086
# ..                 ...
# 226           0.113258
# 227           0.112990
# 228           0.112990
# 229           0.112594
# 230           0.112594
#
# [694 rows x 94 columns]

# %%
summary_df = summarize_taxa_completion(ctrl_taxa_completeness,taxa_col="phylum")
plot_taxa_completion_horizontal(summary_df,taxa_col = "phylum")

# %%
summary_df = summarize_genus_completion(asd_taxa_completeness)
plot_genus_completion_horizontal(summary_df)

# %%
stacked_bar_multiple_group(combine_taxa,level="genus", top_n=15)

# %%
top_asd = pd.read_csv("../data/processed/top_species_ASD.tsv", sep="\t")
top_ctrl = pd.read_csv("../data/processed/top_species_Control.tsv", sep="\t")
top_asd_species = top_asd["Species"]
top_ctrl_species = top_ctrl["Species"]

# %%
# Two example lists
list1 = top_asd_species
list2 = top_ctrl_species

# Convert to sets
set1 = set(list1)
set2 = set(list2)

# Compute set differences and intersection
only_in_1 = set1 - set2
only_in_2 = set2 - set1
in_both = set1 & set2

# Print elements
print("Only in ASD:", only_in_1)
print("Only in Control:", only_in_2)
print("In Both Lists:", in_both)

# Plot the Venn diagram
venn2([set1, set2], set_labels=('ASD', 'Control'))
plt.title("Venn Diagram of Top Species")
plt.show()
# Out:
# Only in ASD: {'Holdemanella_porci', 'Streptococcus_thermophilus', 'Ruminococcus_SGB4421', 'GGB3304_SGB4367', 'Pseudoruminococcus_massiliensis', 'Akkermansia_sp_KLE1798', 'Bacteroides_intestinalis', 'Oscillibacter_sp_ER4', 'Rikenellaceae_bacterium', 'Parabacteroides_merdae', 'Faecalibacillus_intestinalis', 'GGB3001_SGB3992', 'Blautia_glucerasea', 'Clostridiaceae_unclassified_SGB15090', 'Blautia_hansenii', 'GGB9184_SGB14123', 'Vescimonas_coprocola', 'Alistipes_SGB2313', 'Alistipes_ihumii', 'Barnesiella_intestinihominis', 'GGB9345_SGB14311', 'Alistipes_shahii', 'GGB9760_SGB15373'}
# Only in Control: {'GGB9480_SGB14874', 'Enterocloster_SGB14313', 'Bacteroides_thetaiotaomicron', 'Roseburia_intestinalis', 'Bifidobacterium_catenulatum', 'Faecalibacterium_SGB15315', 'Clostridium_sp_AF36_4', 'Phocaeicola_plebeius', 'Prevotella_SGB1615', 'Catenibacterium_SGB4425', 'Roseburia_sp_AF02_12', 'GGB79890_SGB14770', 'Coprococcus_SGB4669', 'Dysosmobacter_welbionis', 'Methanobrevibacter_smithii', 'Bacteroides_stercoris', 'GGB80011_SGB15267', 'GGB9469_SGB14862', 'Clostridium_sp_AF34_10BH', 'Lachnospiraceae_bacterium_Marseille_Q4251', 'Ruminococcus_sp_AF46_10NS', 'GGB79973_SGB14341', 'Bacteroides_faecis'}
# In Both Lists: {'Lacrimispora_celerecrescens', 'Roseburia_inulinivorans', 'Ruminococcus_bicirculans', 'Ruminococcus_sp_BSD2780120874_150323_B10', 'Alistipes_finegoldii', 'Imtechella_halotolerans', 'Clostridiales_Family_XIII_bacterium_BX16', 'Alistipes_onderdonkii', 'Akkermansia_muciniphila', 'GGB80011_SGB15265', 'Blautia_luti', 'Ruminococcus_gnavus', 'Lachnospiraceae_bacterium', 'Blautia_obeum', 'Roseburia_faecis', 'Alistipes_putredinis', 'Coprococcus_eutactus', 'Bacteroides_caccae', 'Anaerobutyricum_soehngenii', 'GGB9713_SGB15249', 'Sellimonas_intestinalis', 'Collinsella_SGB14861', 'Anaerostipes_hadrus', 'Eubacterium_rectale', 'Ruthenibacterium_lactatiformans', 'Adlercreutzia_equolifaciens', 'Parabacteroides_distasonis', 'Anaerobutyricum_hallii', 'Eubacterium_ramulus', 'Bacteroides_sp_Marseille_P3684', 'Blautia_massiliensis', 'Dorea_longicatena', 'Collinsella_aerofaciens', 'Faecalibacterium_SGB15346', 'Ruminococcus_callidus', 'Coprococcus_catus', 'Firmicutes_bacterium_AF16_15', 'GGB3277_SGB4327', 'Faecalicatena_fissicatena', 'Eggerthella_lenta', 'GGB9758_SGB15368', 'Phocaeicola_vulgatus', 'GGB79916_SGB4587', 'Evtepia_gabavorous', 'Ruminococcus_bromii', 'Blautia_SGB4815', 'Faecalibacterium_prausnitzii', 'Blautia_wexlerae', 'Bifidobacterium_longum', 'Candidatus_Cibionibacter_quicibialis', 'Agathobaculum_butyriciproducens', 'GGB3256_SGB4303', 'Roseburia_hominis', 'Bifidobacterium_bifidum', 'Streptococcus_salivarius', 'Fusicatenibacter_saccharivorans', 'Ruminococcus_torques', 'Bifidobacterium_adolescentis', 'Clostridiaceae_bacterium', 'GGB3278_SGB4328', 'Phocaeicola_dorei', 'Bacteroides_fragilis', 'Clostridiales_bacterium_KLE1615', 'Eubacterium_siraeum', 'GGB51647_SGB4348', 'Blautia_faecis', 'Ruminococcus_lactaris', 'Coprococcus_comes', 'Dialister_invisus', 'Bacteroides_ovatus', 'Allobacillus_sp_SKP2_8', 'Gemmiger_formicilis', 'Dorea_formicigenerans', 'Bacteroides_uniformis', 'Bifidobacterium_pseudocatenulatum', 'Prevotella_copri_clade_A', 'Romboutsia_timonensis'}
